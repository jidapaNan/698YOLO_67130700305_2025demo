# %% [markdown]
# ##Student Information
# - 67130700305
# - Jidapa Chanpen
# - BIS698

# %% [markdown]
# ##Set Working Directory

# %%
cd '/content/drive/MyDrive/colab/Lec07-YOLO'
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/colab/Lec07-YOLO'
# /content

# %%
ls
# Out:
# drive/  sample_data/

# %% [markdown]
# ##Install packages

# %%
# !pip -q install ultralytics

# %% [markdown]
# ##Load pretrained YOLO model
